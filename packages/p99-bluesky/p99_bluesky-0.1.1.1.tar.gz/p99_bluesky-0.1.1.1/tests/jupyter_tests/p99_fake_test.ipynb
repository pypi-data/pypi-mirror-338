# %%
import os

os.chdir("/workspaces/p99-bluesky/tests/")

import asyncio
import os

from bluesky.callbacks.best_effort import BestEffortCallback
from bluesky.plans import scan
from bluesky.run_engine import RunEngine
from ophyd.sim import det
from ophyd_async.core import init_devices
from ophyd_async.core.signal import wait_for_value

from p99_bluesky.devices.p99.sample_stage import (
    FilterMotor,
    SampleAngleStage,
)
from soft_motor import SoftThreeAxisStage

bec = BestEffortCallback()
RE = RunEngine({})

# %%
with init_devices(mock=False):
    mock_sampleAngleStage = SampleAngleStage(
        "p99-MO-TABLE-01:", name="mock_sampleAngleStage"
    )
    mock_filter_wheel = FilterMotor(
        "p99-MO-STAGE-02:MP:SELECT", name="mock_filter_wheel"
    )
    xyz_motor = SoftThreeAxisStage("p99-MO-STAGE-02:", name="xyz_motor")
# Out:
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XLLM", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341430015
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XSTOP", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341436655
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:Y.EGU", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341438655
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
# errlog: lost 6 messages
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YRBV", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341445534
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YVAL", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341453465
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YVMAX", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341458705
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YACCL", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341460663
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
# errlog: lost 14 messages
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YDMOV", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341465823
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YLLM", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341470319
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YHLM", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341476150
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YSTOP", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341478966
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:Z.EGU", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341481498
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZVELO", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341486338
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZRBV", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341491124
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZVAL", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341494059
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZVMAX", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341499179
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZACCL", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341504760
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:Z.PREC", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341509085
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZRDBD", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341514474
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZDMOV", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341519115
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZLLM", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341522074
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZHLM", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341526953
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:ZSTOP", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.341530037
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:MP:SELECT", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.365963096
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITETHETA:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.371500087
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITETHETA", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.376825441
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEROLL:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.382071196
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEROLL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.387399741
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEPITCH:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.392168272
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEPITCH", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.397035787
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:X.EGU", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.402401687
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVELO", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.407638533
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XRBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.413214132
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVAL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.418264476
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVMAX", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.423368192
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XACCL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.428696526
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:X.PREC", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.433560680
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XRDBD", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.438418458
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XDMOV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.443737153
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XHLM", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 09:29:04.448676504
# ..................................................................

# %%
from collections import defaultdict

docs = defaultdict(list)
def capture_emitted(name, doc):
        docs[name].append(doc)

RE(scan([det],mock_sampleAngleStage.theta, -1,1, xyz_motor.y, -1, 3, xyz_motor.z,1, -2,xyz_motor.x, 1,-1.7,num = 10),[bec,capture_emitted])
# Out:
# Transient Scan ID: 3     Time: 2024-06-24 09:29:55
# Persistent Unique Scan ID: 'e0cc6744-982d-4779-afc5-0f8628d4e56f'
# New stream: 'primary'
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# |   seq_num |       time | xyz_motor-y | xyz_motor-z | xyz_motor-x | mock_sampleAngleStage-theta |        det |
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# |         1 | 09:29:56.8 |          -1 |           1 |           1 |                          -1 |      1.000 |
# |         2 | 09:29:57.0 |          -1 |           1 |           1 |                          -1 |      1.000 |
# |         3 | 09:29:57.3 |          -0 |           0 |           0 |                          -1 |      1.000 |
# |         4 | 09:29:57.5 |           0 |           0 |           0 |                          -0 |      1.000 |
# |         5 | 09:29:57.7 |           1 |          -0 |          -0 |                          -0 |      1.000 |
# |         6 | 09:29:57.9 |           1 |          -1 |          -1 |                           0 |      1.000 |
# |         7 | 09:29:58.1 |           2 |          -1 |          -1 |                           0 |      1.000 |
# |         8 | 09:29:58.4 |           2 |          -1 |          -1 |                           1 |      1.000 |
# |         9 | 09:29:58.6 |           3 |          -2 |          -1 |                           1 |      1.000 |
# |        10 | 09:29:58.8 |           3 |          -2 |          -2 |                           1 |      1.000 |
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# generator scan ['e0cc6744'] (scan num: 3)
# ('e0cc6744-982d-4779-afc5-0f8628d4e56f',)

# %%
docs
# Out:
# defaultdict(list,
#             {'start': [{'uid': 'e0cc6744-982d-4779-afc5-0f8628d4e56f',
#                'time': 1719221395.4982603,
#                'versions': {'ophyd': '1.9.0', 'bluesky': '1.13.0a3'},
#                'scan_id': 3,
#                'plan_type': 'generator',
#                'plan_name': 'scan',
#                'detectors': ['det'],
#                'motors': ('mock_sampleAngleStage-theta',
#                 'xyz_motor-y',
#                 'xyz_motor-z',
#                 'xyz_motor-x'),
#                'num_points': 10,
#                'num_intervals': 9,
#                'plan_args': {'detectors': ["SynGauss(prefix='', name='det', read_attrs=['val'], configuration_attrs=['Imax', 'center', 'sigma', 'noise', 'noise_multiplier'])"],
#                 'num': 10,
#                 'args': ['<ophyd_async.core.signal.SignalRW object at 0x7fb49f49b890>',
#                  -1,
#                  1,
#                  '<soft_motor.SoftMotor object at 0x7fb4c457ae10>',
#                  -1,
#                  3,
#                  '<soft_motor.SoftMotor object at 0x7fb49f4a3a10>',
#                  1,
#                  -2,
#                  '<soft_motor.SoftMotor object at 0x7fb49f4a0790>',
#                  1,
#                  -1.7],
#                 'per_step': 'None'},
#                'hints': {'dimensions': [(['xyz_motor-y',
#                    'xyz_motor-z',
#                    'xyz_motor-x'],
#                   'primary')]},
#                'plan_pattern': 'inner_product',
#                'plan_pattern_module': 'bluesky.plan_patterns',
#                'plan_pattern_args': {'num': 10,
#                 'args': ['<ophyd_async.core.signal.SignalRW object at 0x7fb49f49b890>',
#                  -1,
#                  1,
#                  '<soft_motor.SoftMotor object at 0x7fb4c457ae10>',
#                  -1,
#                  3,
#                  '<soft_motor.SoftMotor object at 0x7fb49f4a3a10>',
#                  1,
#                  -2,
#                  '<soft_motor.SoftMotor object at 0x7fb49f4a0790>',
#                  1,
#                  -1.7]}}],
#              'descriptor': [{'configuration': {'xyz_motor-z': {'data': {'xyz_motor-z-velocity': 1.5,
#                   'xyz_motor-z-motor_egu': 'mm'},
#                  'timestamps': {'xyz_motor-z-velocity': 1719221379.236406,
#                   'xyz_motor-z-motor_egu': 1719221379.236284},
#                  'data_keys': {'xyz_motor-z-velocity': {'source': 'ca://p99-MO-STAGE-02:ZVELO',
#                    'dtype': 'number',
#                    'shape': [],
#                    'units': '',
#                    'precision': 0,
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': 0.0, 'high': 0.0},
#                     'display': {'low': 0.0, 'high': 0.0},
#                     'warning': {'low': None, 'high': None}}},
#                   'xyz_motor-z-motor_egu': {'source': 'ca://p99-MO-STAGE-02:Z.EGU',
#                    'dtype': 'string',
#                    'shape': [],
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': None, 'high': None},
#                     'display': {'low': None, 'high': None},
#                     'warning': {'low': None, 'high': None}}}}},
#                 'xyz_motor-y': {'data': {'xyz_motor-y-velocity': 1.5,
#                   'xyz_motor-y-motor_egu': 'mm'},
#                  'timestamps': {'xyz_motor-y-velocity': 1719221379.236252,
#                   'xyz_motor-y-motor_egu': 1719221379.236107},
#                  'data_keys': {'xyz_motor-y-velocity': {'source': 'ca://p99-MO-STAGE-02:YVELO',
#                    'dtype': 'number',
#                    'shape': [],
#                    'units': '',
#                    'precision': 0,
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': 0.0, 'high': 0.0},
#                     'display': {'low': 0.0, 'high': 0.0},
#                     'warning': {'low': None, 'high': None}}},
#                   'xyz_motor-y-motor_egu': {'source': 'ca://p99-MO-STAGE-02:Y.EGU',
#                    'dtype': 'string',
#                    'shape': [],
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': None, 'high': None},
#                     'display': {'low': None, 'high': None},
#                     'warning': {'low': None, 'high': None}}}}},
#                 'mock_sampleAngleStage-theta': {'data': {},
#                  'timestamps': {},
#                  'data_keys': {}},
#                 'det': {'data': {'det_Imax': 1,
#                   'det_center': 0,
#                   'det_sigma': 1,
#                   'det_noise': 'none',
#                   'det_noise_multiplier': 1},
#                  'timestamps': {'det_Imax': 1719221343.7320824,
#                   'det_center': 1719221343.732079,
#                   'det_sigma': 1719221343.7320876,
#                   'det_noise': 1719221343.732065,
#                   'det_noise_multiplier': 1719221343.7320747},
#                  'data_keys': OrderedDict([('det_Imax',
#                                {'source': 'SIM:det_Imax',
#                                 'dtype': 'integer',
#                                 'shape': []}),
#                               ('det_center',
#                                {'source': 'SIM:det_center',
#                                 'dtype': 'integer',
#                                 'shape': []}),
#                               ('det_sigma',
#                                {'source': 'SIM:det_sigma',
#                                 'dtype': 'integer',
#                                 'shape': []}),
#                               ('det_noise',
#                                {'source': 'SIM:det_noise',
#                                 'dtype': 'integer',
#                                 'shape': [],
#                                 'enum_strs': ('none', 'poisson', 'uniform')}),
#                               ('det_noise_multiplier',
#                                {'source': 'SIM:det_noise_multiplier',
#                                 'dtype': 'integer',
#                                 'shape': []})])},
#                 'xyz_motor-x': {'data': {'xyz_motor-x-velocity': 1.5,
#                   'xyz_motor-x-motor_egu': 'mm'},
#                  'timestamps': {'xyz_motor-x-velocity': 1719221379.236073,
#                   'xyz_motor-x-motor_egu': 1719221379.235902},
#                  'data_keys': {'xyz_motor-x-velocity': {'source': 'ca://p99-MO-STAGE-02:XVELO',
#                    'dtype': 'number',
#                    'shape': [],
#                    'units': '',
#                    'precision': 0,
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': 0.0, 'high': 0.0},
#                     'display': {'low': 0.0, 'high': 0.0},
#                     'warning': {'low': None, 'high': None}}},
#                   'xyz_motor-x-motor_egu': {'source': 'ca://p99-MO-STAGE-02:X.EGU',
#                    'dtype': 'string',
#                    'shape': [],
#                    'limits': {'alarm': {'low': None, 'high': None},
#                     'control': {'low': None, 'high': None},
#                     'display': {'low': None, 'high': None},
#                     'warning': {'low': None, 'high': None}}}}}},
#                'data_keys': {'xyz_motor-z': {'source': 'ca://p99-MO-STAGE-02:ZRBV',
#                  'dtype': 'number',
#                  'shape': [],
#                  'units': '',
#                  'precision': 0,
#                  'limits': {'alarm': {'low': None, 'high': None},
#                   'control': {'low': 0.0, 'high': 0.0},
#                   'display': {'low': 0.0, 'high': 0.0},
#                   'warning': {'low': None, 'high': None}},
#                  'object_name': 'xyz_motor-z'},
#                 'xyz_motor-y': {'source': 'ca://p99-MO-STAGE-02:YRBV',
#                  'dtype': 'number',
#                  'shape': [],
#                  'units': '',
#                  'precision': 0,
#                  'limits': {'alarm': {'low': None, 'high': None},
#                   'control': {'low': 0.0, 'high': 0.0},
#                   'display': {'low': 0.0, 'high': 0.0},
#                   'warning': {'low': None, 'high': None}},
#                  'object_name': 'xyz_motor-y'},
#                 'mock_sampleAngleStage-theta': {'source': 'ca://p99-MO-TABLE-01:WRITETHETA:RBV',
#                  'dtype': 'number',
#                  'shape': [],
#                  'units': '',
#                  'precision': 0,
#                  'limits': {'alarm': {'low': None, 'high': None},
#                   'control': {'low': 0.0, 'high': 0.0},
#                   'display': {'low': 0.0, 'high': 0.0},
#                   'warning': {'low': None, 'high': None}},
#                  'object_name': 'mock_sampleAngleStage-theta'},
#                 'det': {'source': 'SIM:det',
#                  'dtype': 'number',
#                  'shape': [],
#                  'precision': 3,
#                  'object_name': 'det'},
#                 'xyz_motor-x': {'source': 'ca://p99-MO-STAGE-02:XRBV',
#                  'dtype': 'number',
#                  'shape': [],
#                  'units': '',
#                  'precision': 0,
#                  'limits': {'alarm': {'low': None, 'high': None},
#                   'control': {'low': 0.0, 'high': 0.0},
#                   'display': {'low': 0.0, 'high': 0.0},
#                   'warning': {'low': None, 'high': None}},
#                  'object_name': 'xyz_motor-x'}},
#                'name': 'primary',
#                'object_keys': {'xyz_motor-z': ['xyz_motor-z'],
#                 'xyz_motor-y': ['xyz_motor-y'],
#                 'mock_sampleAngleStage-theta': ['mock_sampleAngleStage-theta'],
#                 'det': ['det'],
#                 'xyz_motor-x': ['xyz_motor-x']},
#                'run_start': 'e0cc6744-982d-4779-afc5-0f8628d4e56f',
#                'time': 1719221396.8439317,
#                'uid': 'f7cbbac7-7492-4f36-9102-4246287b805f',
#                'hints': {'xyz_motor-z': {'fields': ['xyz_motor-z']},
#                 'xyz_motor-y': {'fields': ['xyz_motor-y']},
#                 'det': {'fields': ['det']},
#                 'xyz_motor-x': {'fields': ['xyz_motor-x']}}}],
#              'event': [{'uid': '5d0ae6bc-6f0d-4fa2-a5a5-6802e1fd553a',
#                'time': 1719221396.857711,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': -1.0,
#                 'xyz_motor-y': -1.0,
#                 'xyz_motor-z': 1.0,
#                 'xyz_motor-x': 1.0},
#                'timestamps': {'det': 1719221396.8417976,
#                 'mock_sampleAngleStage-theta': 1719221395.50054,
#                 'xyz_motor-y': 1719221396.841305,
#                 'xyz_motor-z': 1719221396.841276,
#                 'xyz_motor-x': 1719221396.841331},
#                'seq_num': 1,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '0aec44f0-0b27-449f-bcd2-db1565cfefb8',
#                'time': 1719221397.0859363,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': -0.7777777777777778,
#                 'xyz_motor-y': -0.5555555555555556,
#                 'xyz_motor-z': 0.6666666666666667,
#                 'xyz_motor-x': 0.7},
#                'timestamps': {'det': 1719221397.0844276,
#                 'mock_sampleAngleStage-theta': 1719221396.94849,
#                 'xyz_motor-y': 1719221397.083989,
#                 'xyz_motor-z': 1719221397.08397,
#                 'xyz_motor-x': 1719221397.08401},
#                'seq_num': 2,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '8ecf5e2b-b469-40e8-8396-83fd761c5eb5',
#                'time': 1719221397.3083544,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': -0.5555555555555556,
#                 'xyz_motor-y': -0.11111111111111116,
#                 'xyz_motor-z': 0.33333333333333337,
#                 'xyz_motor-x': 0.3999999999999999},
#                'timestamps': {'det': 1719221397.306915,
#                 'mock_sampleAngleStage-theta': 1719221397.16547,
#                 'xyz_motor-y': 1719221397.306289,
#                 'xyz_motor-z': 1719221397.306245,
#                 'xyz_motor-x': 1719221397.306338},
#                'seq_num': 3,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '9c7ff9e8-7f72-49f9-b6a8-78c1af52766d',
#                'time': 1719221397.5213056,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': -0.33333333333333337,
#                 'xyz_motor-y': 0.33333333333333326,
#                 'xyz_motor-z': 0.0,
#                 'xyz_motor-x': 0.09999999999999987},
#                'timestamps': {'det': 1719221397.520056,
#                 'mock_sampleAngleStage-theta': 1719221397.386211,
#                 'xyz_motor-y': 1719221397.519498,
#                 'xyz_motor-z': 1719221397.51947,
#                 'xyz_motor-x': 1719221397.519524},
#                'seq_num': 4,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': 'd47a95a8-71ac-4c9b-95fd-e52d35d1e4f8',
#                'time': 1719221397.7438316,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': -0.11111111111111116,
#                 'xyz_motor-y': 0.7777777777777777,
#                 'xyz_motor-z': -0.33333333333333326,
#                 'xyz_motor-x': -0.20000000000000018},
#                'timestamps': {'det': 1719221397.742733,
#                 'mock_sampleAngleStage-theta': 1719221397.609922,
#                 'xyz_motor-y': 1719221397.742268,
#                 'xyz_motor-z': 1719221397.742183,
#                 'xyz_motor-x': 1719221397.742293},
#                'seq_num': 5,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '468e6e22-2446-40db-849a-bc692deebdef',
#                'time': 1719221397.966436,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': 0.11111111111111116,
#                 'xyz_motor-y': 1.2222222222222223,
#                 'xyz_motor-z': -0.6666666666666665,
#                 'xyz_motor-x': -0.5000000000000002},
#                'timestamps': {'det': 1719221397.9654012,
#                 'mock_sampleAngleStage-theta': 1719221397.828826,
#                 'xyz_motor-y': 1719221397.964856,
#                 'xyz_motor-z': 1719221397.964827,
#                 'xyz_motor-x': 1719221397.964881},
#                'seq_num': 6,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': 'f2b1753c-9959-4748-ae2a-662faeef95c2',
#                'time': 1719221398.1890557,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': 0.33333333333333326,
#                 'xyz_motor-y': 1.6666666666666665,
#                 'xyz_motor-z': -1.0,
#                 'xyz_motor-x': -0.8000000000000003},
#                'timestamps': {'det': 1719221398.1877246,
#                 'mock_sampleAngleStage-theta': 1719221398.045989,
#                 'xyz_motor-y': 1719221398.186975,
#                 'xyz_motor-z': 1719221398.186936,
#                 'xyz_motor-x': 1719221398.187026},
#                'seq_num': 7,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '5a14f8fd-aedf-43bd-91b6-478dcd04edf4',
#                'time': 1719221398.4112546,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': 0.5555555555555554,
#                 'xyz_motor-y': 2.1111111111111107,
#                 'xyz_motor-z': -1.333333333333333,
#                 'xyz_motor-x': -1.1000000000000005},
#                'timestamps': {'det': 1719221398.4104261,
#                 'mock_sampleAngleStage-theta': 1719221398.275661,
#                 'xyz_motor-y': 1719221398.409895,
#                 'xyz_motor-z': 1719221398.409861,
#                 'xyz_motor-x': 1719221398.409921},
#                'seq_num': 8,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': 'f9357df0-2e6c-4677-b9b0-1f65fa5dd149',
#                'time': 1719221398.6336896,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': 0.7777777777777777,
#                 'xyz_motor-y': 2.5555555555555554,
#                 'xyz_motor-z': -1.6666666666666665,
#                 'xyz_motor-x': -1.4000000000000004},
#                'timestamps': {'det': 1719221398.6328592,
#                 'mock_sampleAngleStage-theta': 1719221398.495769,
#                 'xyz_motor-y': 1719221398.632365,
#                 'xyz_motor-z': 1719221398.632338,
#                 'xyz_motor-x': 1719221398.632388},
#                'seq_num': 9,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'},
#               {'uid': '62926786-7630-484f-8a6b-44ed95c95f3a',
#                'time': 1719221398.8564837,
#                'data': {'det': 1.0,
#                 'mock_sampleAngleStage-theta': 1.0,
#                 'xyz_motor-y': 3.0,
#                 'xyz_motor-z': -2.0,
#                 'xyz_motor-x': -1.7},
#                'timestamps': {'det': 1719221398.8556666,
#                 'mock_sampleAngleStage-theta': 1719221398.720327,
#                 'xyz_motor-y': 1719221398.855138,
#                 'xyz_motor-z': 1719221398.855078,
#                 'xyz_motor-x': 1719221398.855195},
#                'seq_num': 10,
#                'filled': {},
#                'descriptor': 'f7cbbac7-7492-4f36-9102-4246287b805f'}],
#              'stop': [{'uid': 'a52a596e-a0ad-4792-89a8-2042745b76de',
#                'time': 1719221398.9359682,
#                'run_start': 'e0cc6744-982d-4779-afc5-0f8628d4e56f',
#                'exit_status': 'success',
#                'reason': '',
#                'num_events': {'primary': 10}}]})
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "host.containers.internal:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1237
#     Current Time: Mon Jun 24 2024 10:15:45.257179777
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XLLM", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.932428698
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XHLM", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.932434654
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "errlog: lost 27 messages
#     Current Time: Mon Jun 24 2024 10:15:52.932440765
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YVAL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.932443595
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YVMAX", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.932447229
# ..................................................................
# CA.Client.Exception...............................................
# errlog: lost 143 messages
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:MP:SELECT", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.933346012
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITETHETA:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.933725364
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITETHETA", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.934280327
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEROLL:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.934766729
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEROLL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.935237199
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEPITCH:RBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.935741318
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-TABLE-01:WRITEPITCH", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.936243083
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:X.EGU", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.936924763
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVELO", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.937293372
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XRBV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.938267256
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVAL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.938757720
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XVMAX", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.939255818
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XACCL", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.939711426
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:X.PREC", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.940239088
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XRDBD", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.940770824
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:XDMOV", Connecting to: 172.23.241.223:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.941272884
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "p99-MO-STAGE-02:YDMOV", Connecting to: host.containers.internal:5064, Ignored: 192.168.122.1:5064"
#     Source File: modules/ca/src/client/cac.cpp line 1320
#     Current Time: Mon Jun 24 2024 10:15:52.941750392
# ..................................................................

# %%
RE(scan([mock_sampleAngleStage.theta, det], xyz_motor.y, 3, -1, xyz_motor.z,-2, 1,xyz_motor.x, -1.7,1,num = 40),bec)
# Out:
# Transient Scan ID: 6     Time: 2024-06-14 12:51:47
# Persistent Unique Scan ID: '72b465ad-6f6b-4faf-9828-3958e41e7c1b'
# New stream: 'primary'
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# |   seq_num |       time | xyz_motor-y | xyz_motor-z | xyz_motor-x | mock_sampleAngleStage-theta |        det |
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# |         1 | 12:51:47.8 |       3.000 |      -2.000 |      -1.700 |                       0.000 |      1.000 |
# |         2 | 12:51:48.4 |       2.897 |      -1.923 |      -1.631 |                       0.000 |      1.000 |
# |         3 | 12:51:49.0 |       2.795 |      -1.846 |      -1.562 |                       0.000 |      1.000 |
# |         4 | 12:51:49.6 |       2.692 |      -1.769 |      -1.492 |                       0.000 |      1.000 |
# |         5 | 12:51:50.2 |       2.590 |      -1.692 |      -1.423 |                       0.000 |      1.000 |
# |         6 | 12:51:50.8 |       2.487 |      -1.615 |      -1.354 |                       0.000 |      1.000 |
# |         7 | 12:51:51.4 |       2.385 |      -1.538 |      -1.285 |                       0.000 |      1.000 |
# |         8 | 12:51:51.9 |       2.282 |      -1.462 |      -1.215 |                       0.000 |      1.000 |
# |         9 | 12:51:52.6 |       2.179 |      -1.385 |      -1.146 |                       0.000 |      1.000 |
# |        10 | 12:51:53.1 |       2.077 |      -1.308 |      -1.077 |                       0.000 |      1.000 |
# |        11 | 12:51:53.7 |       1.974 |      -1.231 |      -1.008 |                       0.000 |      1.000 |
# |        12 | 12:51:54.3 |       1.872 |      -1.154 |      -0.938 |                       0.000 |      1.000 |
# |        13 | 12:51:54.9 |       1.769 |      -1.077 |      -0.869 |                       0.000 |      1.000 |
# |        14 | 12:51:55.5 |       1.667 |      -1.000 |      -0.800 |                       0.000 |      1.000 |
# |        15 | 12:51:56.1 |       1.564 |      -0.923 |      -0.731 |                       0.000 |      1.000 |
# |        16 | 12:51:56.6 |       1.488 |      -0.846 |      -0.662 |                       0.000 |      1.000 |
# |        17 | 12:51:57.3 |       1.359 |      -0.769 |      -0.592 |                       0.000 |      1.000 |
# |        18 | 12:51:57.8 |       1.256 |      -0.692 |      -0.523 |                       0.000 |      1.000 |
# |        19 | 12:51:58.5 |       1.154 |      -0.615 |      -0.454 |                       0.000 |      1.000 |
# |        20 | 12:51:59.1 |       1.051 |      -0.538 |      -0.385 |                       0.000 |      1.000 |
# |        21 | 12:51:59.7 |       0.949 |      -0.462 |      -0.315 |                       0.000 |      1.000 |
# |        22 | 12:52:00.2 |       0.846 |      -0.385 |      -0.246 |                       0.000 |      1.000 |
# |        23 | 12:52:00.8 |       0.744 |      -0.308 |      -0.177 |                       0.000 |      1.000 |
# |        24 | 12:52:01.4 |       0.641 |      -0.231 |      -0.108 |                       0.000 |      1.000 |
# |        25 | 12:52:02.0 |       0.538 |      -0.154 |      -0.038 |                       0.000 |      1.000 |
# |        26 | 12:52:02.6 |       0.436 |      -0.077 |       0.031 |                       0.000 |      1.000 |
# |        27 | 12:52:03.2 |       0.333 |       0.000 |       0.100 |                       0.000 |      1.000 |
# |        28 | 12:52:03.8 |       0.231 |       0.077 |       0.169 |                       0.000 |      1.000 |
# |        29 | 12:52:04.4 |       0.128 |       0.154 |       0.238 |                       0.000 |      1.000 |
# |        30 | 12:52:05.0 |       0.026 |       0.231 |       0.308 |                       0.000 |      1.000 |
# |        31 | 12:52:05.6 |      -0.077 |       0.308 |       0.377 |                       0.000 |      1.000 |
# |        32 | 12:52:06.2 |      -0.179 |       0.385 |       0.446 |                       0.000 |      1.000 |
# |        33 | 12:52:06.8 |      -0.282 |       0.462 |       0.515 |                       0.000 |      1.000 |
# |        34 | 12:52:07.4 |      -0.385 |       0.538 |       0.585 |                       0.000 |      1.000 |
# |        35 | 12:52:08.0 |      -0.487 |       0.615 |       0.654 |                       0.000 |      1.000 |
# |        36 | 12:52:08.6 |      -0.590 |       0.692 |       0.723 |                       0.000 |      1.000 |
# |        37 | 12:52:09.2 |      -0.692 |       0.769 |       0.792 |                       0.000 |      1.000 |
# |        38 | 12:52:09.8 |      -0.795 |       0.846 |       0.862 |                       0.000 |      1.000 |
# |        39 | 12:52:10.4 |      -0.897 |       0.923 |       0.931 |                       0.000 |      1.000 |
# |        40 | 12:52:11.0 |      -1.000 |       1.000 |       1.000 |                       0.000 |      1.000 |
# +-----------+------------+-------------+-------------+-------------+-----------------------------+------------+
# generator scan ['72b465ad'] (scan num: 6)
# ('72b465ad-6f6b-4faf-9828-3958e41e7c1b',)

# %%
result = asyncio.gather(xyz_motor.y.user_setpoint.set(-3),xyz_motor.z.user_setpoint.set(3))

# %%
result = asyncio.gather(xyz_motor.z.user_readback.get_value(),xyz_motor.y.user_readback.get_value(),xyz_motor.x.user_readback.get_value())

# %%
result

# %%
result = asyncio.gather(wait_for_value(xyz_motor.z.motor_done_move,True, timeout = None))

# %%
result
