# %%
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

import panpdf

matplotlib_inline.backend_inline.set_matplotlib_formats("retina")
panpdf.set_formatter("matplotlib", "pgf")
panpdf.add_fonts("Harano Aji Gothic")

# %%
fig, ax = plt.subplots()
ax.text(
    0.5,
    0.5,
    "There are あいう in between!",
    family=["DejaVu Sans", "Harano Aji Gothic"],
    ha="center",
)
# Out:
# Text(0.5, 0.5, 'There are あいう in between!')
# %% Creator: Matplotlib, PGF backend
# %%
# %% To include the figure in your LaTeX document, write
# %%   \input{<filename>.pgf}
# %%
# %% Make sure the required packages are loaded in your preamble
# %%   \usepackage{pgf}
# %%
# %% Also ensure that all the required font packages are loaded; for instance,
# %% the lmodern package is sometimes necessary when using math font.
# %%   \usepackage{lmodern}
# %%
# %% Figures using additional raster images can only be included by \input if
# %% they are in the same directory as the main LaTeX file. For loading figures
# %% from other directories you can use the `import` package
# %%   \usepackage{import}
# %%
# %% and then include the figures with
# %%   \import{<path to file>}{<filename>.pgf}
# %%
# %% Matplotlib used the following preamble
# %%   \def\mathdefault#1{#1}
# %%   \everymath=\expandafter{\the\everymath\displaystyle}
# %%
# %%   \ifdefined\pdftexversion\else  % non-pdftex case.
# %%     \usepackage{fontspec}
# %%     \setmainfont{DejaVuSerif.ttf}[Path=\detokenize{C:/Users/daizu/Documents/GitHub/panpdf/.venv/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/}]
# %%     \setsansfont{DejaVuSans.ttf}[Path=\detokenize{C:/Users/daizu/Documents/GitHub/panpdf/.venv/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/}]
# %%     \setmonofont{DejaVuSansMono.ttf}[Path=\detokenize{C:/Users/daizu/Documents/GitHub/panpdf/.venv/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/}]
# %%   \fi
# %%   \makeatletter\@ifpackageloaded{underscore}{}{\usepackage[strings]{underscore}}\makeatother
# %%
# \begingroup%
# \makeatletter%
# \begin{pgfpicture}%
# \pgfpathrectangle{\pgfpointorigin}{\pgfqpoint{5.588541in}{4.180397in}}%
# \pgfusepath{use as bounding box, clip}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{5.588541in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{5.588541in}{4.180397in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{4.180397in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetmiterjoin%
# \definecolor{currentfill}{rgb}{1.000000,1.000000,1.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.000000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetstrokeopacity{0.000000}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.418102in}{0.331635in}}%
# \pgfpathlineto{\pgfqpoint{5.378102in}{0.331635in}}%
# \pgfpathlineto{\pgfqpoint{5.378102in}{4.027635in}}%
# \pgfpathlineto{\pgfqpoint{0.418102in}{4.027635in}}%
# \pgfpathlineto{\pgfqpoint{0.418102in}{0.331635in}}%
# \pgfpathclose%
# \pgfusepath{fill}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.418102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{1.410102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=1.410102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{2.402102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.402102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.4}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{3.394102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=3.394102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.6}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{4.386102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=4.386102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.8}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{0.000000in}{-0.048611in}}{\pgfqpoint{0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{0.000000in}{-0.048611in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{5.378102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=5.378102in,y=0.234413in,,top]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1.0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{0.331635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=0.278873in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{1.070835in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=1.018073in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.2}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{1.810035in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=1.757273in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.4}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{2.549235in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=2.496473in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.6}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{3.288435in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=3.235673in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}0.8}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetbuttcap%
# \pgfsetroundjoin%
# \definecolor{currentfill}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetfillcolor{currentfill}%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfsys@defobject{currentmarker}{\pgfqpoint{-0.048611in}{0.000000in}}{\pgfqpoint{-0.000000in}{0.000000in}}{%
# \pgfpathmoveto{\pgfqpoint{-0.000000in}{0.000000in}}%
# \pgfpathlineto{\pgfqpoint{-0.048611in}{0.000000in}}%
# \pgfusepath{stroke,fill}%
# }%
# \begin{pgfscope}%
# \pgfsys@transformshift{0.418102in}{4.027635in}%
# \pgfsys@useobject{currentmarker}{}%
# \end{pgfscope}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=0.100000in, y=3.974873in, left, base]{\color{textcolor}{\sffamily\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}1.0}}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.418102in}{0.331635in}}%
# \pgfpathlineto{\pgfqpoint{0.418102in}{4.027635in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{5.378102in}{0.331635in}}%
# \pgfpathlineto{\pgfqpoint{5.378102in}{4.027635in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.418102in}{0.331635in}}%
# \pgfpathlineto{\pgfqpoint{5.378102in}{0.331635in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \pgfsetrectcap%
# \pgfsetmiterjoin%
# \pgfsetlinewidth{0.803000pt}%
# \definecolor{currentstroke}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{currentstroke}%
# \pgfsetdash{}{0pt}%
# \pgfpathmoveto{\pgfqpoint{0.418102in}{4.027635in}}%
# \pgfpathlineto{\pgfqpoint{5.378102in}{4.027635in}}%
# \pgfusepath{stroke}%
# \end{pgfscope}%
# \begin{pgfscope}%
# \definecolor{textcolor}{rgb}{0.000000,0.000000,0.000000}%
# \pgfsetstrokecolor{textcolor}%
# \pgfsetfillcolor{textcolor}%
# \pgftext[x=2.898102in,y=2.179635in,,base]{\color{textcolor}{\ifdefined\pdftexversion\else\setmainfont{DejaVu Sans}\rmfamily\fi\fontsize{10.000000}{12.000000}\selectfont\catcode`\^=\active\def^{\ifmmode\sp\else\^{}\fi}\catcode`\%=\active\def%{\%}There are あいう in between!}}%
# \end{pgfscope}%
# \end{pgfpicture}%
# \makeatother%
# \endgroup%
