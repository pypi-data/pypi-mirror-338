# %% [markdown]
# # Tutorial 8: Spatial Navigation
#
# Spatial navigation lets you work with PDF content based on the physical layout of elements on the page. It's perfect for finding elements relative to each other and extracting information in context.

# %%
from natural_pdf import PDF

# Load a PDF
pdf = PDF("pdfs/01-practice.pdf")
page = pdf.pages[0]

# Find the title of the document
title = page.find('text:contains("Jungle Health")')

# Visualize our starting point
title.show(color="red", label="Document Title")

# Display the title text
title.text
# Out:
# 'Jungle Health and Safety Inspection Service'

# %% [markdown]
# ## Finding Elements Above and Below

# %%
# Create a region below the title
region_below = title.below(height=100)

# Visualize the region
region_below.show(color="blue", label="Below Title")

# Find and extract text from this region
text_below = region_below.extract_text()
text_below
# Out:
# 'I INS-UP70N51NCL41R N S - U P 7 0 N 5 1 N C L 4 1 R S Site:  i t e :   D Durham’s Meatpacking Chicago, Ill. u r h a m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l . D Date:  a t e :     F February 3, 1905 e b r u a r y   3 ,   1 9 0 5 V Violation Count:  i o l a t i o n   C o u n t :   7 7'

# %% [markdown]
# ## Finding Content Between Elements

# %%
# Find two labels to serve as boundaries
site_label = page.find('text:contains("Site:")')
date_label = page.find('text:contains("Date:")')

# Get the region between these labels
between_region = site_label.below(
    include_element=True,     # Include starting element
    until='text:contains("Date:")',  # Stop at this element
    include_endpoint=False    # Don't include ending element
)

# Visualize the region between labels
between_region.show(color="green", label="Between")

# Extract text from this bounded area
between_region.extract_text()
# Out:
# 'S Site:  i t e :   D Durham’s Meatpacking Chicago, Ill. u r h a m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l .'

# %% [markdown]
# ## Navigating Left and Right

# %%
# Find a field label
site_label = page.find('text:contains("Site:")')

# Get the content to the right (the field value)
value_region = site_label.right(width=200)

# Visualize the label and value regions
site_label.show(color="red", label="Label")
value_region.show(color="blue", label="Value")

# Extract just the value text
value_region.extract_text()
# Out:
# 'D Durham’s Meatpacking Chicago, Ill. u r h a m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l .   F February 3, 1905 e b r u a r y   3 ,   1 9 0 5 Violation Count:  i o n   C o u n t :   7 7 a r y :   W o r s t   o f   a n y ,   h o w e v e r ,   w e r e   t h e   f e r t i l i z   p e o p l e   c o u l d   n o t   b e   s h o w n   t o   t h e   v i s i t o r   -   f o visitor at a hundred yards, and as for the other men, who worked in tank rooms full of steam, and in    a t   a   h u n d r e d   y a r d s ,   a n d   a s   f o r   t h e   o t h e r   m e o f   w h i c h   t h e r e   w e r e   o p e n   v a t s   n e a r   t h e   l e v e l into the vats; and when they were fished out, there was never enough of them left to be worth  e   v a t s ;   a n d   w h e n   t h e y   w e r e   f i s h e d   o u t ,   t h e r e exhibiting - sometimes they would be overlooked for days, till all but the bones of them had gone out t i n g   -   s o m e t i m e s   t h e y   w o u l d   b e   o v e r l o o k e d   f to the world as Durham’s Pure Leaf Lard! w o r l d   a s   D u r h a m ’ s   P u r e   L e a f   L a r d ! Violations t i o n s t e D Description e s c r i p t i o n 7 U Unsanitary Working Conditions. n s a n i t a r y   W o r k i n g   C o n d i t i o n s . I Inadequate Protective Equipment. n a d e q u a t e   P r o t e c t i v e   E q u i p m e n t . I Ineffective Injury Prevention. n e f f e c t i v e   I n j u r y   P r e v e n t i o n . F Failure to Properly Store Hazardous Materials. a i l u r e   t o   P r o p e r l y   S t o r e   H a z a r d o u s   M L Lack of Adequate Fire Safety Measures. a c k   o f   A d e q u a t e   F i r e   S a f e t y   M e a s u r I Inadequate Ventilation Systems. n a d e q u a t e   V e n t i l a t i o n   S y s t e m s . 7 I Insufficient Employee Training for Safe Work Practices. n s u f f i c i e n t   E m p l o y e e   T r a i n i n g   f o r   S a f J u n g l e   H e a l'

# %% [markdown]
# ## Finding Adjacent Elements

# %%
# Start with a label element
label = page.find('text:contains("Site:")')

# Find the next and previous elements in reading order
next_elem = label.next()
prev_elem = label.prev()

# Visualize all three elements
label.show(color="red", label="Current")
next_elem.show(color="green", label="Next") if next_elem else None
prev_elem.show(color="blue", label="Previous") if prev_elem else None

# Show the text of adjacent elements
{
    "current": label.text,
    "next": next_elem.text if next_elem else "None",
    "previous": prev_elem.text if prev_elem else "None"
}
# Out:
# {'current': 'Site: ', 'next': 'i', 'previous': 'S'}

# %% [markdown]
# ## Combining with Element Selectors

# %%
# Find a section label
summary = page.find('text:contains("Summary:")')

# Find the next bold text element
next_bold = summary.next('text:bold', limit=20)

# Find the nearest line element
nearest_line = summary.nearest('line')

# Visualize what we found
summary.show(color="red", label="Summary")
next_bold.show(color="blue", label="Next Bold") if next_bold else None
nearest_line.show(color="green", label="Nearest Line") if nearest_line else None

# Show the content we found
{
    "summary": summary.text,
    "next_bold": next_bold.text if next_bold else "None found",
    "nearest_line": nearest_line if nearest_line else "None found"
}
# Out:
# {'summary': 'Summary: ',
#  'next_bold': 'u',
#  'nearest_line': <LineElement type=horizontal width=2.0 bbox=(50, 352, 550, 352)>}

# %% [markdown]
# ## Extracting Table Rows with Spatial Navigation

# %%
# Find a table heading
table_heading = page.find('text:contains("Statute")')
table_heading.show(color="purple", label="Table Header")

# Extract table rows using spatial navigation
rows = []
current = table_heading

# Get the next 4 rows
for i in range(4):
    # Find the next row below the current one
    next_row = current.below(height=15)
    
    if next_row:
        rows.append(next_row)
        current = next_row  # Move to the next row
    else:
        break

# Visualize all found rows
page.clear_highlights()
for i, row in enumerate(rows):
    row.highlight(label=f"Row {i+1}")
page.to_image(width=700)
# Out:
# <PIL.Image.Image image mode=RGBA size=700x778>

# %%
# Extract text from each row
[row.extract_text() for row in rows]
# Out:
# ['',
#  '',
#  '5 5.8.3 . 8 . 3 I Inadequate Protective Equipment. n a d e q u a t e   P r o t e c t i v e   E q u i p m e n t . S Serious e r i o u s',
#  '6 6.3.9 . 3 . 9 I Ineffective Injury Prevention. n e f f e c t i v e   I n j u r y   P r e v e n t i o n . S Serious e r i o u s']

# %% [markdown]
# ## Extracting Key-Value Pairs

# %%
# Find all potential field labels (text with a colon)
labels = page.find_all('text:contains(":")') 

# Visualize the labels
labels.show(color="blue", label="Labels")

# Extract key-value pairs
field_data = {}

for label in labels:
    # Clean up the label text
    key = label.text.strip().rstrip(':')
    
    # Skip if not a proper label
    if not key:
        continue
    
    # Get the value to the right
    value = label.right(width=200).extract_text().strip()
    
    # Add to our collection
    field_data[key] = value

# Show the extracted data
field_data
# Out:
# {'Site': 'D Durham’s Meatpacking Chicago, Ill. u r h a m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l .   F February 3, 1905 e b r u a r y   3 ,   1 9 0 5 Violation Count:  i o n   C o u n t :   7 7 a r y :   W o r s t   o f   a n y ,   h o w e v e r ,   w e r e   t h e   f e r t i l i z   p e o p l e   c o u l d   n o t   b e   s h o w n   t o   t h e   v i s i t o r   -   f o visitor at a hundred yards, and as for the other men, who worked in tank rooms full of steam, and in    a t   a   h u n d r e d   y a r d s ,   a n d   a s   f o r   t h e   o t h e r   m e o f   w h i c h   t h e r e   w e r e   o p e n   v a t s   n e a r   t h e   l e v e l into the vats; and when they were fished out, there was never enough of them left to be worth  e   v a t s ;   a n d   w h e n   t h e y   w e r e   f i s h e d   o u t ,   t h e r e exhibiting - sometimes they would be overlooked for days, till all but the bones of them had gone out t i n g   -   s o m e t i m e s   t h e y   w o u l d   b e   o v e r l o o k e d   f to the world as Durham’s Pure Leaf Lard! w o r l d   a s   D u r h a m ’ s   P u r e   L e a f   L a r d ! Violations t i o n s t e D Description e s c r i p t i o n 7 U Unsanitary Working Conditions. n s a n i t a r y   W o r k i n g   C o n d i t i o n s . I Inadequate Protective Equipment. n a d e q u a t e   P r o t e c t i v e   E q u i p m e n t . I Ineffective Injury Prevention. n e f f e c t i v e   I n j u r y   P r e v e n t i o n . F Failure to Properly Store Hazardous Materials. a i l u r e   t o   P r o p e r l y   S t o r e   H a z a r d o u s   M L Lack of Adequate Fire Safety Measures. a c k   o f   A d e q u a t e   F i r e   S a f e t y   M e a s u r I Inadequate Ventilation Systems. n a d e q u a t e   V e n t i l a t i o n   S y s t e m s . 7 I Insufficient Employee Training for Safe Work Practices. n s u f f i c i e n t   E m p l o y e e   T r a i n i n g   f o r   S a f J u n g l e   H e a l',
#  'Date': 'Durham’s Meatpacking Chicago, Ill. u r h a m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l . F February 3, 1905 e b r u a r y   3 ,   1 9 0 5 Violation Count:  n   C o u n t :   7 7 r y :   W o r s t   o f   a n y ,   h o w e v e r ,   w e r e   t h e   f e r t i l i z e e o p l e   c o u l d   n o t   b e   s h o w n   t o   t h e   v i s i t o r   -   f o r   visitor at a hundred yards, and as for the other men, who worked in tank rooms full of steam, and in  t   a   h u n d r e d   y a r d s ,   a n d   a s   f o r   t h e   o t h e r   m e n , some of which there were open vats near the level of the floor, their peculiar trouble was that they fell f   w h i c h   t h e r e   w e r e   o p e n   v a t s   n e a r   t h e   l e v e l   o into the vats; and when they were fished out, there was never enough of them left to be worth    v a t s ;   a n d   w h e n   t h e y   w e r e   f i s h e d   o u t ,   t h e r e   exhibiting - sometimes they would be overlooked for days, till all but the bones of them had gone out n g   -   s o m e t i m e s   t h e y   w o u l d   b e   o v e r l o o k e d   f o r to the world as Durham’s Pure Leaf Lard! o r l d   a s   D u r h a m ’ s   P u r e   L e a f   L a r d ! i o n s e D Description e s c r i p t i o n U Unsanitary Working Conditions. n s a n i t a r y   W o r k i n g   C o n d i t i o n s . I Inadequate Protective Equipment. n a d e q u a t e   P r o t e c t i v e   E q u i p m e n t . I Ineffective Injury Prevention. n e f f e c t i v e   I n j u r y   P r e v e n t i o n . F Failure to Properly Store Hazardous Materials. a i l u r e   t o   P r o p e r l y   S t o r e   H a z a r d o u s   M a L Lack of Adequate Fire Safety Measures. a c k   o f   A d e q u a t e   F i r e   S a f e t y   M e a s u r e s I Inadequate Ventilation Systems. n a d e q u a t e   V e n t i l a t i o n   S y s t e m s . I Insufficient Employee Training for Safe Work Practices. n s u f f i c i e n t   E m p l o y e e   T r a i n i n g   f o r   S a f e   J u n g l e   H e a l t h',
#  'Violation Count': 'Durham’s Meatpacking Chicago, Ill. a t p a c k i n g     C h i c a g o ,   I l l .   1 9 0 5 Worst of any, however, were the fertilizer men, and those who served in the cooking rooms. o f   a n y ,   h o w e v e r ,   w e r e   t h e   f e r t i l i z e r   m e n ,   a n d These people could not be shown to the visitor - for the odor of a fertilizer man would scare any ordinary  d   n o t   b e   s h o w n   t o   t h e   v i s i t o r   -   f o r   t h e   o d o r   o f visitor at a hundred yards, and as for the other men, who worked in tank rooms full of steam, and in    y a r d s ,   a n d   a s   f o r   t h e   o t h e r   m e n ,   w h o   w o r k e some of which there were open vats near the level of the floor, their peculiar trouble was that they fell e   w e r e   o p e n   v a t s   n e a r   t h e   l e v e l   o f   t h e   f l o o r ,   into the vats; and when they were fished out, there was never enough of them left to be worth  h e n   t h e y   w e r e   f i s h e d   o u t ,   t h e r e   w a s   n e v e r   e exhibiting - sometimes they would be overlooked for days, till all but the bones of them had gone out m e s   t h e y   w o u l d   b e   o v e r l o o k e d   f o r   d a y s ,   t i l l   a to the world as Durham’s Pure Leaf Lard! h a m ’ s   P u r e   L e a f   L a r d ! i p t i o n Unsanitary Working Conditions. i t a r y   W o r k i n g   C o n d i t i o n s . Inadequate Protective Equipment. u a t e   P r o t e c t i v e   E q u i p m e n t . Ineffective Injury Prevention. t i v e   I n j u r y   P r e v e n t i o n . Failure to Properly Store Hazardous Materials.   t o   P r o p e r l y   S t o r e   H a z a r d o u s   M a t e r i a l s . Lack of Adequate Fire Safety Measures. f   A d e q u a t e   F i r e   S a f e t y   M e a s u r e s . Inadequate Ventilation Systems. u a t e   V e n t i l a t i o n   S y s t e m s . Insufficient Employee Training for Safe Work Practices. c i e n t   E m p l o y e e   T r a i n i n g   f o r   S a f e   W o r k   P r a c t J Jungle Health and Safety Inspection Service u n g l e   H e a l t h   a n d   S a f e t y   I n',
#  'Summary': 'Durham’s Meatpacking Chicago, Ill. m ’ s   M e a t p a c k i n g     C h i c a g o ,   I l l . February 3, 1905 a r y   3 ,   1 9 0 5 o u n t :   7 7 W o r s t   o f   a n y ,   h o w e v e r ,   w e r e   t h e   f e r t i l i z e r   m e These people could not be shown to the visitor - for the odor of a fertilizer man would scare any ordinary  e   c o u l d   n o t   b e   s h o w n   t o   t h e   v i s i t o r   -   f o r   t h e   o visitor at a hundred yards, and as for the other men, who worked in tank rooms full of steam, and in  u n d r e d   y a r d s ,   a n d   a s   f o r   t h e   o t h e r   m e n ,   w h o some of which there were open vats near the level of the floor, their peculiar trouble was that they fell c h   t h e r e   w e r e   o p e n   v a t s   n e a r   t h e   l e v e l   o f   t h e into the vats; and when they were fished out, there was never enough of them left to be worth  ;   a n d   w h e n   t h e y   w e r e   f i s h e d   o u t ,   t h e r e   w a s   n exhibiting - sometimes they would be overlooked for days, till all but the bones of them had gone out o m e t i m e s   t h e y   w o u l d   b e   o v e r l o o k e d   f o r   d a y to the world as Durham’s Pure Leaf Lard! a s   D u r h a m ’ s   P u r e   L e a f   L a r d ! D Description e s c r i p t i o n U Unsanitary Working Conditions. n s a n i t a r y   W o r k i n g   C o n d i t i o n s . I Inadequate Protective Equipment. n a d e q u a t e   P r o t e c t i v e   E q u i p m e n t . I Ineffective Injury Prevention. n e f f e c t i v e   I n j u r y   P r e v e n t i o n . F Failure to Properly Store Hazardous Materials. a i l u r e   t o   P r o p e r l y   S t o r e   H a z a r d o u s   M a t e r i a L Lack of Adequate Fire Safety Measures. a c k   o f   A d e q u a t e   F i r e   S a f e t y   M e a s u r e s . I Inadequate Ventilation Systems. n a d e q u a t e   V e n t i l a t i o n   S y s t e m s . I Insufficient Employee Training for Safe Work Practices. n s u f f i c i e n t   E m p l o y e e   T r a i n i n g   f o r   S a f e   W o r J u n g l e   H e a l t h   a n d   S'}

# %% [markdown]
# Spatial navigation mimics how humans read documents, letting you navigate content based on physical relationships between elements. It's especially useful for extracting structured data from forms, tables, and formatted documents.
