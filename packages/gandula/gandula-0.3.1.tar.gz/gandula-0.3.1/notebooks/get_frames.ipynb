# %%
import gandula
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import gandula
#
# File ~/Documents/UFMG/SALab/gandula/.venv/lib/python3.11/site-packages/gandula/__init__.py:9
#       7 from .api.competition import get_competition as get_competition
#       8 from .api.competition import get_competitions as get_competitions
# ----> 9 from .api.match import get_enhanced as get_enhanced
#      10 from .api.match import get_frames as get_frames
#      11 from .api.match import get_match as get_match
#
# File ~/Documents/UFMG/SALab/gandula/.venv/lib/python3.11/site-packages/gandula/api/match.py:12
#      10 from ..providers.pff.schema.event import PFF_Event, PFF_Game, PFF_Roster
#      11 from ..providers.pff.schema.tracking import PFF_Frame
# ---> 12 from ..utils.pff_enhancer import (
#      13     enhance_match,
#      14     filter_frames_with_actionable_events,
#      15     get_enhanceable_event_ids,
#      16 )
#      19 logger = structlog.get_logger()
#      22 def get_match_events(
#      23     match_id: int, *, api_url: str | None = None, api_key: str | None = None
#      24 ) -> list[PFF_Event]:
#
# File ~/Documents/UFMG/SALab/gandula/.venv/lib/python3.11/site-packages/gandula/utils/pff_enhancer.py:427
#     413         # if raw_frame.get('game_event_type') in [
#     414         #     PFF_Frame_GameEventType.OUT_OF_PLAY.value,
#     415         #     PFF_Frame_GameEventType.END_OF_HALF.value,
#    (...)
#     418         # if raw_frame.get('frameNum') == raw_frame['game_event']['start_frame']:
#     419         #     return raw_frame
#     421     return None
#     423 def pff_frames_to_dataframes(
#     424     frames: list[PFF_Frame],
#     425     return_frames: bool = True,
#     426     return_players: bool = True
# --> 427 ) -> tuple(pd.DataFrame | None, pd.DataFrame | None):
#     428     """
#     429     Convert a list of PFF_Frame objects into DataFrames for frames and players.
#     430
#    (...)
#     438       If a DataFrame is not requested, its position in the tuple will be None.
#     439     """
#     441     frames_df = None
#
# TypeError: tuple expected at most 1 argument, got 2

# %%
frames = gandula.get_frames(
    '/Users/thiago/football/ufmg/gandula/_data/tracking/premier-league/22-23',
    4621,
)
# Out:
# Loading frames from match 4621: 0 frames [00:00, ? frames/s]
# Validating frames:   0%|          | 0/171701 [00:00<?, ? frames/s]

# %%
gandula.view(frames[0])
# Out:
# <Axes: >
